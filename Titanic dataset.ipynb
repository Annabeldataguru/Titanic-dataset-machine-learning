# %% [markdown]
# # problem statement
# Data cleaning,exploration,build machine learning model to predict the survival rate of passenger

# %% [markdown]
# # Data importation and Acessing on Titanic dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Dataset is all about a titanic ship conveying passengers to different cities and it was boarded by 891 passengers.The dataset also tells us about the age bracket of all passengers both female and male along side their ticket number and fare. The passengers that Survived are rated by 0 while dead passengers are rated by 1

# %%
#randomly print first five rows
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# randomly print first ten rows
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 783          784         0       3                   Johnston, Mr. Andrew G
# 361          362         0       2                del Carlo, Mr. Sebastiano
# 745          746         0       1             Crosby, Capt. Edward Gifford
# 472          473         1       2  West, Mrs. Edwy Arthur (Ada Mary Worth)
# 585          586         1       1                      Taussig, Miss. Ruth
# 822          823         0       1          Reuchlin, Jonkheer. John George
# 564          565         0       3           Meanwell, Miss. (Marion Ogden)
# 747          748         1       2                    Sinkkonen, Miss. Anna
# 96            97         0       1                Goldschmidt, Mr. George B
# 604          605         1       1          Homer, Mr. Harry ("Mr E Haven")
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# ...

# %%
# check for missing values
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# check for a duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
#checking for non missing values
missing_value=df.isna().sum()
missing_value[missing_value.values>0]
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#to check the summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#The Dataset consist of 891 entries of passengers,12 columns,5 int datatype and 2 float datatype which consist of 83.7kb.

# %%
# check for columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# return the dimension of the dataframe
df.shape
# Out:
# (891, 12)

# %%
# to calculate the percentage 
percentage=(df.isna().sum()/df.shape[0])*100
percentage
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
# to calculate the percentage 
percentage=(df.isna().sum()/df.shape[0])*100
percentage 
percentage=(df.isna().sum()/df.shape[0])*100
mis_values=df.isna().sum()#missing value
#join the missing value and percntage of the missing values
kas=pd.concat([mis_values,percentage],axis=1,keys=["mis_values","percentage"])
#to check the non misinfg value of the dataset with percentage
kas[kas["mis_values"]>0]
# Out:
# Empty DataFrame
# Columns: [mis_values, percentage]
# Index: []

# %%
#to check the non misinfg value of the dataset with percentage
kas[kas["mis_values"]>0]
# Out:
#           mis_values  percentage
# Age              177   19.865320
# Cabin            687   77.104377
# Embarked           2    0.224467

# %% [markdown]
# # DATA CLEANNG

# %%
# fill the missing values in age with calculated mean
Age_mean=round(df.Age.mean(),0)
df.Age.fillna(Age_mean,inplace=True)

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    30.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# drop cabin column since it having missing value more than 50%
df.drop(columns=["Cabin"],inplace=True)

# %%
# fill the mssing values in embark with mode
mode=df.Embarked.mode()[0]
df.Embarked.fillna(mode,inplace=True)

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
# remove all the duplicate records
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# extract all the tittle of passengers as new column
split=lambda x:x.split()[1].strip(".")
df.Name.apply(split)
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Name, Length: 891, dtype: object

# %%
df["Tittle"]=df.Name.apply(split)

# %%
df.assign()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#it make changes based on the function you have defined
df.assign(Tittle=df.Name.apply(split),kaz=1,fatty=-100)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# to count the columns in title
df["Tittle"].value_counts()
# Out:
# Mr        502
# Miss      179
# Mrs       121
# Master     40
# others     36
# Dr          7
# Rev         6
# Name: Tittle, dtype: int64

# %%
split=lambda x:x.split()[1].strip(".").strip(",")
df["Tittle"]=df.Name.apply(split)
df["Tittle"]=df["Tittle"].replace(["y","Planke","Impe","Gordon","Col","Mlle","Major","Melkebeke","Jonkheer",
                    "Shawah","the","Velde","Capt","Messemaeker","Carlo","Ms","Mme","Steen",
                    "Mulder","Pelsmaeker","Walle","der","Billiard","Don","Cruyssen"],"others")

# %%
df.drop(columns=["Ttile"],inplace=True)

# %%
# change the datatype of age column to int
df["Age"]=df["Age"].astype(int)
df["SibSp"]=df["SibSp"].astype("category")
df["Parch"]=df["Parch"].astype("category")

# %% [markdown]
# # Data Exploration
# is the process of using chart to understand the pattern of dataset

# %%
survive_rate=df["Survived"].value_counts()
survive_rate.index=["Dead","Alive"]
survive_rate
# Out:
# Dead     549
# Alive    342
# Name: Survived, dtype: int64

# %% [markdown]
# # tools to plot chart
# seaborn
# matplot
# pandas plot

# %%
# using pandas plot
survive_rate.plot(kind="bar")
plt.show()# to remove all the inscription that comes along the chart

# %%
# using matplot
import matplotlib.pyplot as plt

# %%
plt.bar(x=survive_rate.index,height=survive_rate.values)
plt.show()# to remove all the inscription that comes along the chart

# %%
import seaborn as sns

# %%
sns.barplot(x=survive_rate.index,y=survive_rate.values)
plt.show() # to remove all the inscription that comes along the chart

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df.Age)
plt.show()
